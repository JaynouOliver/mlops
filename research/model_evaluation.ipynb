# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Subhr\\Documents\\github\\ML\\mlops'

# %%
os.chdir("../")

# %%
os.environ["MLFLOW_TRACKING_URI"]="https://dagshub.com/JaynouOliver/mlops.mlflow"
os.environ["MLFLOW_TRACKING_USERNAME"]="JaynouOliver"
os.environ["MLFLOW_TRACKING_PASSWORD"]="6819348457da04756807717ef7e8c3f1995bb7d8"

# %%
import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\Subhr\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
tf.keras.models.load_model("artifacts/training/model.h5")
# Out:
# WARNING:tensorflow:From c:\Users\Subhr\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Subhr\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class EvaluationConfig:
    path_of_model: Path
    training_data: Path
    all_params: dict
    mlflow_uri: str
    params_image_size: list
    params_batch_size: int

# %%
from src.cnnClassifier.constants import *
from src.cnnClassifier.utils.common import read_yaml, create_directories, save_json

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])

    
    def get_evaluation_config(self) -> EvaluationConfig:
        eval_config = EvaluationConfig(
            path_of_model="artifacts/training/model.h5",
            training_data="artifacts/data_ingestion/data",
            mlflow_uri="https://dagshub.com/JaynouOliver/mlops.mlflow",
            all_params=self.params,
            params_image_size=self.params.IMAGE_SIZE,
            params_batch_size=self.params.BATCH_SIZE
        )
        return eval_config

# %%
# %pip install mlflow
# Out:
# Collecting mlflow
#   Obtaining dependency information for mlflow from https://files.pythonhosted.org/packages/ce/d4/756d5cd1304fbbaac8624ce93cedba804237586d69c17ac1cdaf6daefd52/mlflow-2.10.2-py3-none-any.whl.metadata
#   Downloading mlflow-2.10.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (8.0.4)
# Requirement already satisfied: cloudpickle<4 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: entrypoints<1 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (0.4)
# Collecting gitpython<4,>=2.1.0 (from mlflow)
#   Obtaining dependency information for gitpython<4,>=2.1.0 from https://files.pythonhosted.org/packages/67/c7/995360c87dd74e27539ccbfecddfb58e08f140d849fcd7f35d2ed1a5f80f/GitPython-3.1.42-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.42-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (6.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (3.20.3)
# Requirement already satisfied: pytz<2024 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (2023.3.post1)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: packaging<24 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (23.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (6.0.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow)
#   Obtaining dependency information for sqlparse<1,>=0.4.0 from https://files.pythonhosted.org/packages/98/5a/66d7c9305baa9f11857f247d4ba761402cea75db6058ff850ed7128957b7/sqlparse-0.4.4-py3-none-any.whl.metadata
#   Downloading sqlparse-0.4.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Obtaining dependency information for alembic!=1.10.0,<2 from https://files.pythonhosted.org/packages/7f/50/9fb3a5c80df6eb6516693270621676980acd6d5a9a7efdbfa273f8d616c7/alembic-1.13.1-py3-none-any.whl.metadata
#   Downloading alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Obtaining dependency information for docker<8,>=4.0.0 from https://files.pythonhosted.org/packages/18/bd/9706c10bb12e05043ef138dc8d412cfd17f29c8df0fb28ad71c96a98785d/docker-7.0.0-py3-none-any.whl.metadata
#   Downloading docker-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: Flask<4 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: numpy<2 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (1.24.3)
# Requirement already satisfied: scipy<2 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (1.11.1)
# Requirement already satisfied: pandas<3 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (2.0.3)
# Collecting querystring-parser<2 (from mlflow)
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (1.4.39)
# Requirement already satisfied: scikit-learn<2 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (1.3.0)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (11.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: matplotlib<4 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (3.7.2)
# Collecting waitress<3 (from mlflow)
#   Obtaining dependency information for waitress<3 from https://files.pythonhosted.org/packages/58/6a/b4b5c582e04e837e4422cab6ec9de7fc10ca7ad7f4e370bb89d280d39552/waitress-2.1.2-py3-none-any.whl.metadata
#   Downloading waitress-2.1.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\subhr\anaconda3\lib\site-packages (from mlflow) (3.1.2)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Obtaining dependency information for Mako from https://files.pythonhosted.org/packages/2b/8d/9f11d0b9ac521febb806e7f30dc5982d0f4f5821217712c59005fbc5c1e3/Mako-1.3.2-py3-none-any.whl.metadata
#   Downloading Mako-1.3.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\subhr\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.7.1)
# Requirement already satisfied: colorama in c:\users\subhr\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\subhr\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (1.26.16)
# Requirement already satisfied: pywin32>=304 in c:\users\subhr\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\subhr\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\subhr\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.0.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=2.1.0->mlflow)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\subhr\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\subhr\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\subhr\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\subhr\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\subhr\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\subhr\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\subhr\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\subhr\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\subhr\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\subhr\anaconda3\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: six in c:\users\subhr\anaconda3\lib\site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\subhr\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\subhr\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\subhr\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\subhr\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\subhr\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\subhr\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (2.0.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading mlflow-2.10.2-py3-none-any.whl (19.5 MB)
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/19.5 MB 825.8 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/19.5 MB 751.6 kB/s eta 0:00:26
#    ---------------------------------------- 0.1/19.5 MB 722.1 kB/s eta 0:00:27
#    ---------------------------------------- 0.2/19.5 MB 706.2 kB/s eta 0:00:28
#    ---------------------------------------- 0.2/19.5 MB 787.7 kB/s eta 0:00:25
#    ---------------------------------------- 0.2/19.5 MB 811.5 kB/s eta 0:00:24
#     --------------------------------------- 0.3/19.5 MB 787.7 kB/s eta 0:00:25
#     --------------------------------------- 0.3/19.5 MB 791.9 kB/s eta 0:00:25
#     --------------------------------------- 0.3/19.5 MB 807.1 kB/s eta 0:00:24
#     --------------------------------------- 0.4/19.5 MB 809.6 kB/s eta 0:00:24
#     --------------------------------------- 0.4/19.5 MB 815.2 kB/s eta 0:00:24
#     --------------------------------------- 0.5/19.5 MB 838.1 kB/s eta 0:00:23
#    - -------------------------------------- 0.5/19.5 MB 823.9 kB/s eta 0:00:24
#    - -------------------------------------- 0.5/19.5 MB 832.0 kB/s eta 0:00:23
#    - -------------------------------------- 0.6/19.5 MB 838.1 kB/s eta 0:00:23
#    - -------------------------------------- 0.6/19.5 MB 837.1 kB/s eta 0:00:23
#    - -------------------------------------- 0.7/19.5 MB 870.1 kB/s eta 0:00:22
#    - -------------------------------------- 0.7/19.5 MB 873.7 kB/s eta 0:00:22
#    - -------------------------------------- 0.8/19.5 MB 870.2 kB/s eta 0:00:22
#    - -------------------------------------- 0.8/19.5 MB 889.4 kB/s eta 0:00:22
#    - -------------------------------------- 0.9/19.5 MB 907.1 kB/s eta 0:00:21
#    - -------------------------------------- 0.9/19.5 MB 905.4 kB/s eta 0:00:21
#    - -------------------------------------- 1.0/19.5 MB 933.6 kB/s eta 0:00:20
#    -- ------------------------------------- 1.0/19.5 MB 930.9 kB/s eta 0:00:20
#    -- ------------------------------------- 1.1/19.5 MB 937.5 kB/s eta 0:00:20
#    -- ------------------------------------- 1.1/19.5 MB 965.5 kB/s eta 0:00:20
#    -- ------------------------------------- 1.2/19.5 MB 958.4 kB/s eta 0:00:20
#    -- ------------------------------------- 1.2/19.5 MB 971.4 kB/s eta 0:00:19
#    -- ------------------------------------- 1.3/19.5 MB 986.9 kB/s eta 0:00:19
#    -- ------------------------------------- 1.3/19.5 MB 991.2 kB/s eta 0:00:19
#    -- ------------------------------------- 1.4/19.5 MB 1.0 MB/s eta 0:00:19
#    --- ------------------------------------ 1.5/19.5 MB 1.0 MB/s eta 0:00:18
#    --- ------------------------------------ 1.5/19.5 MB 1.0 MB/s eta 0:00:18
#    --- ------------------------------------ 1.6/19.5 MB 1.0 MB/s eta 0:00:18
#    --- ------------------------------------ 1.6/19.5 MB 1.0 MB/s eta 0:00:18
#    --- ------------------------------------ 1.7/19.5 MB 1.1 MB/s eta 0:00:17
#    --- ------------------------------------ 1.8/19.5 MB 1.1 MB/s eta 0:00:17
#    --- ------------------------------------ 1.8/19.5 MB 1.1 MB/s eta 0:00:17
#    --- ------------------------------------ 1.9/19.5 MB 1.1 MB/s eta 0:00:17
#    ---- ----------------------------------- 2.0/19.5 MB 1.1 MB/s eta 0:00:17
#    ---- ----------------------------------- 2.1/19.5 MB 1.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 2.1/19.5 MB 1.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 2.2/19.5 MB 1.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 2.3/19.5 MB 1.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 2.3/19.5 MB 1.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 2.4/19.5 MB 1.1 MB/s eta 0:00:15
#    ----- ---------------------------------- 2.5/19.5 MB 1.2 MB/s eta 0:00:15
#    ----- ---------------------------------- 2.5/19.5 MB 1.2 MB/s eta 0:00:15
#    ----- ---------------------------------- 2.6/19.5 MB 1.2 MB/s eta 0:00:15
#    ----- ---------------------------------- 2.7/19.5 MB 1.2 MB/s eta 0:00:15
#    ----- ---------------------------------- 2.8/19.5 MB 1.2 MB/s eta 0:00:14
#    ----- ---------------------------------- 2.9/19.5 MB 1.2 MB/s eta 0:00:14
#    ----- ---------------------------------- 2.9/19.5 MB 1.2 MB/s eta 0:00:14
#    ------ --------------------------------- 3.0/19.5 MB 1.2 MB/s eta 0:00:14
#    ------ --------------------------------- 3.1/19.5 MB 1.2 MB/s eta 0:00:14
#    ------ --------------------------------- 3.1/19.5 MB 1.2 MB/s eta 0:00:14
#    ------ --------------------------------- 3.2/19.5 MB 1.3 MB/s eta 0:00:14
#    ------ --------------------------------- 3.3/19.5 MB 1.3 MB/s eta 0:00:13
#    ------ --------------------------------- 3.4/19.5 MB 1.3 MB/s eta 0:00:13
#    ------- -------------------------------- 3.4/19.5 MB 1.3 MB/s eta 0:00:13
#    ------- -------------------------------- 3.5/19.5 MB 1.3 MB/s eta 0:00:13
#    ------- -------------------------------- 3.6/19.5 MB 1.3 MB/s eta 0:00:13
#    ------- -------------------------------- 3.7/19.5 MB 1.3 MB/s eta 0:00:13
#    ------- -------------------------------- 3.7/19.5 MB 1.3 MB/s eta 0:00:12
#    ------- -------------------------------- 3.8/19.5 MB 1.3 MB/s eta 0:00:12
#    -------- ------------------------------- 3.9/19.5 MB 1.3 MB/s eta 0:00:12
#    -------- ------------------------------- 4.0/19.5 MB 1.3 MB/s eta 0:00:12
#    -------- ------------------------------- 4.1/19.5 MB 1.4 MB/s eta 0:00:12
#    -------- ------------------------------- 4.2/19.5 MB 1.4 MB/s eta 0:00:12
#    -------- ------------------------------- 4.2/19.5 MB 1.4 MB/s eta 0:00:12
#    -------- ------------------------------- 4.3/19.5 MB 1.4 MB/s eta 0:00:12
#    --------- ------------------------------ 4.4/19.5 MB 1.4 MB/s eta 0:00:11
#    --------- ------------------------------ 4.5/19.5 MB 1.4 MB/s eta 0:00:11
#    --------- ------------------------------ 4.6/19.5 MB 1.4 MB/s eta 0:00:11
#    --------- ------------------------------ 4.7/19.5 MB 1.4 MB/s eta 0:00:11
#    --------- ------------------------------ 4.8/19.5 MB 1.4 MB/s eta 0:00:11
#    --------- ------------------------------ 4.8/19.5 MB 1.4 MB/s eta 0:00:11
#    ---------- ----------------------------- 5.0/19.5 MB 1.4 MB/s eta 0:00:11
#    ---------- ----------------------------- 5.0/19.5 MB 1.4 MB/s eta 0:00:10
#    ---------- ----------------------------- 5.1/19.5 MB 1.5 MB/s eta 0:00:10
#    ---------- ----------------------------- 5.2/19.5 MB 1.5 MB/s eta 0:00:10
#    ---------- ----------------------------- 5.3/19.5 MB 1.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 5.4/19.5 MB 1.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 5.5/19.5 MB 1.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 5.6/19.5 MB 1.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 5.6/19.5 MB 1.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 5.7/19.5 MB 1.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 5.8/19.5 MB 1.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 5.9/19.5 MB 1.5 MB/s eta 0:00:10
#    ------------ --------------------------- 6.0/19.5 MB 1.5 MB/s eta 0:00:09
#    ------------ --------------------------- 6.1/19.5 MB 1.5 MB/s eta 0:00:09
#    ------------ --------------------------- 6.2/19.5 MB 1.5 MB/s eta 0:00:09
#    ------------ --------------------------- 6.3/19.5 MB 1.5 MB/s eta 0:00:09
#    ------------- -------------------------- 6.4/19.5 MB 1.5 MB/s eta 0:00:09
#    ------------- -------------------------- 6.5/19.5 MB 1.6 MB/s eta 0:00:09
#    ------------- -------------------------- 6.6/19.5 MB 1.6 MB/s eta 0:00:09
#    ------------- -------------------------- 6.7/19.5 MB 1.6 MB/s eta 0:00:09
#    ------------- -------------------------- 6.8/19.5 MB 1.6 MB/s eta 0:00:09
#    -------------- ------------------------- 6.9/19.5 MB 1.6 MB/s eta 0:00:08
#    -------------- ------------------------- 7.0/19.5 MB 1.6 MB/s eta 0:00:08
#    -------------- ------------------------- 7.1/19.5 MB 1.6 MB/s eta 0:00:08
#    -------------- ------------------------- 7.2/19.5 MB 1.6 MB/s eta 0:00:08
#    --------------- ------------------------ 7.3/19.5 MB 1.6 MB/s eta 0:00:08
#    --------------- ------------------------ 7.5/19.5 MB 1.6 MB/s eta 0:00:08
#    --------------- ------------------------ 7.6/19.5 MB 1.7 MB/s eta 0:00:08
#    --------------- ------------------------ 7.7/19.5 MB 1.7 MB/s eta 0:00:08
#    ---------------- ----------------------- 7.8/19.5 MB 1.7 MB/s eta 0:00:08
#    ---------------- ----------------------- 7.9/19.5 MB 1.7 MB/s eta 0:00:07
#    ---------------- ----------------------- 8.0/19.5 MB 1.7 MB/s eta 0:00:07
#    ---------------- ----------------------- 8.1/19.5 MB 1.7 MB/s eta 0:00:07
#    ---------------- ----------------------- 8.3/19.5 MB 1.7 MB/s eta 0:00:07
#    ----------------- ---------------------- 8.4/19.5 MB 1.7 MB/s eta 0:00:07
#    ----------------- ---------------------- 8.5/19.5 MB 1.7 MB/s eta 0:00:07
#    ----------------- ---------------------- 8.6/19.5 MB 1.7 MB/s eta 0:00:07
#    ----------------- ---------------------- 8.7/19.5 MB 1.7 MB/s eta 0:00:07
#    ------------------ --------------------- 8.8/19.5 MB 1.7 MB/s eta 0:00:07
#    ------------------ --------------------- 8.8/19.5 MB 1.7 MB/s eta 0:00:07
#    ------------------ --------------------- 8.9/19.5 MB 1.7 MB/s eta 0:00:07
#    ------------------ --------------------- 9.0/19.5 MB 1.7 MB/s eta 0:00:07
#    ------------------ --------------------- 9.1/19.5 MB 1.7 MB/s eta 0:00:07
#    ------------------ --------------------- 9.1/19.5 MB 1.7 MB/s eta 0:00:07
#    ------------------ --------------------- 9.2/19.5 MB 1.7 MB/s eta 0:00:06
#    ------------------ --------------------- 9.3/19.5 MB 1.7 MB/s eta 0:00:06
#    ------------------- -------------------- 9.4/19.5 MB 1.7 MB/s eta 0:00:06
#    ------------------- -------------------- 9.5/19.5 MB 1.7 MB/s eta 0:00:06
#    ------------------- -------------------- 9.6/19.5 MB 1.8 MB/s eta 0:00:06
#    ------------------- -------------------- 9.8/19.5 MB 1.8 MB/s eta 0:00:06
#    -------------------- ------------------- 9.9/19.5 MB 1.8 MB/s eta 0:00:06
#    -------------------- ------------------- 10.0/19.5 MB 1.8 MB/s eta 0:00:06
#    -------------------- ------------------- 10.1/19.5 MB 1.8 MB/s eta 0:00:06
#    --------------------- ------------------ 10.3/19.5 MB 1.8 MB/s eta 0:00:06
#    --------------------- ------------------ 10.4/19.5 MB 1.8 MB/s eta 0:00:05
#    --------------------- ------------------ 10.6/19.5 MB 1.9 MB/s eta 0:00:05
#    --------------------- ------------------ 10.6/19.5 MB 1.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 10.8/19.5 MB 2.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 10.9/19.5 MB 2.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 11.0/19.5 MB 2.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 11.2/19.5 MB 2.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 11.3/19.5 MB 2.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.4/19.5 MB 2.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.5/19.5 MB 2.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.7/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 11.8/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 11.9/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 12.0/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 12.2/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------- -------------- 12.3/19.5 MB 2.3 MB/s eta 0:00:04
#    ------------------------- -------------- 12.4/19.5 MB 2.3 MB/s eta 0:00:04
#    ------------------------- -------------- 12.6/19.5 MB 2.3 MB/s eta 0:00:04
#    -------------------------- ------------- 12.7/19.5 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 12.9/19.5 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 13.0/19.5 MB 2.4 MB/s eta 0:00:03
#    -------------------------- ------------- 13.1/19.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 13.2/19.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 13.3/19.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 13.5/19.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 13.6/19.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.8/19.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.9/19.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 14.0/19.5 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.2/19.5 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.3/19.5 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.5/19.5 MB 2.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 14.6/19.5 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 14.7/19.5 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 14.9/19.5 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 15.0/19.5 MB 2.6 MB/s eta 0:00:02
#    ------------------------------- -------- 15.2/19.5 MB 2.6 MB/s eta 0:00:02
#    ------------------------------- -------- 15.3/19.5 MB 2.7 MB/s eta 0:00:02
#    ------------------------------- -------- 15.5/19.5 MB 2.7 MB/s eta 0:00:02
#    -------------------------------- ------- 15.6/19.5 MB 2.7 MB/s eta 0:00:02
#    -------------------------------- ------- 15.8/19.5 MB 2.7 MB/s eta 0:00:02
#    -------------------------------- ------- 15.9/19.5 MB 2.8 MB/s eta 0:00:02
#    -------------------------------- ------- 16.1/19.5 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 16.2/19.5 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 16.4/19.5 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 16.6/19.5 MB 2.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.7/19.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.8/19.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 17.0/19.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 17.1/19.5 MB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.2/19.5 MB 2.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.3/19.5 MB 2.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.4/19.5 MB 2.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.5/19.5 MB 2.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.6/19.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 17.7/19.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 17.7/19.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 17.8/19.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 17.9/19.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 18.1/19.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 18.2/19.5 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 18.3/19.5 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 18.4/19.5 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 18.5/19.5 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 18.6/19.5 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 18.6/19.5 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 18.8/19.5 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 18.8/19.5 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 18.9/19.5 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 19.0/19.5 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.5 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  19.2/19.5 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  19.3/19.5 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  19.5/19.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  19.5/19.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  19.5/19.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 19.5/19.5 MB 2.6 MB/s eta 0:00:00
# Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.4 kB ? eta -:--:--
#    ---------------------------- ----------- 163.8/233.4 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 233.4/233.4 kB 3.5 MB/s eta 0:00:00
# Downloading docker-7.0.0-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.6 kB ? eta -:--:--
#    --------------------------------- ------ 122.9/147.6 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 147.6/147.6 kB 3.0 MB/s eta 0:00:00
# Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#    ---------------------------------------- 0.0/195.4 kB ? eta -:--:--
#    --------------------------------- ------ 163.8/195.4 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 195.4/195.4 kB 3.9 MB/s eta 0:00:00
# Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#    ---------------------------------------- 41.2/41.2 kB 2.1 MB/s eta 0:00:00
# Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#    ---------------------------------------- 57.7/57.7 kB 3.0 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Downloading Mako-1.3.2-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.7 kB ? eta -:--:--
#    ---------------------------------------- 78.7/78.7 kB 4.6 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: waitress, sqlparse, smmap, querystring-parser, Mako, gitdb, docker, alembic, gitpython, mlflow
# Successfully installed Mako-1.3.2 alembic-1.13.1 docker-7.0.0 gitdb-4.0.11 gitpython-3.1.42 mlflow-2.10.2 querystring-parser-1.2.4 smmap-5.0.1 sqlparse-0.4.4 waitress-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from pathlib import Path
import mlflow
import mlflow.keras
from urllib.parse import urlparse

# %%
class Evaluation:
    def __init__(self, config: EvaluationConfig):
        self.config = config

    
    def _valid_generator(self):

        datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.30
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )


    @staticmethod
    def load_model(path: Path) -> tf.keras.Model:
        return tf.keras.models.load_model(path)
    

    def evaluation(self):
        self.model = self.load_model(self.config.path_of_model)
        self._valid_generator()
        self.score = model.evaluate(self.valid_generator)
        self.save_score()

    def save_score(self):
        scores = {"loss": self.score[0], "accuracy": self.score[1]}
        save_json(path=Path("scores.json"), data=scores)

    
    def log_into_mlflow(self):
        mlflow.set_registry_uri(self.config.mlflow_uri)
        tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme
        
        with mlflow.start_run():
            mlflow.log_params(self.config.all_params)
            mlflow.log_metrics(
                {"loss": self.score[0], "accuracy": self.score[1]}
            )
            # Model registry does not work with file store
            if tracking_url_type_store != "file":

                # Register the model
                # There are other ways to use the Model Registry, which depends on the use case,
                # please refer to the doc for more information:
                # https://mlflow.org/docs/latest/model-registry.html#api-workflow
                mlflow.keras.log_model(self.model, "model", registered_model_name="VGG16Model")
            else:
                mlflow.keras.log_model(self.model, "model")

# %%
class Evaluation:
    def __init__(self, config: EvaluationConfig):
        self.config = config

    
    def _valid_generator(self):

        datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.30
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )


    @staticmethod
    def load_model(path: Path) -> tf.keras.Model:
        return tf.keras.models.load_model(path)
    

    def evaluation(self):
        self.model = self.load_model(self.config.path_of_model)
        self._valid_generator()
        self.score = self.model.evaluate(self.valid_generator)
        self.save_score()

    def save_score(self):
        scores = {"loss": self.score[0], "accuracy": self.score[1]}
        save_json(path=Path("scores.json"), data=scores)

    
    def log_into_mlflow(self):
        mlflow.set_registry_uri(self.config.mlflow_uri)
        tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme
        
        with mlflow.start_run():
            mlflow.log_params(self.config.all_params)
            mlflow.log_metrics(
                {"loss": self.score[0], "accuracy": self.score[1]}
            )
            # Model registry does not work with file store
            if tracking_url_type_store != "file":

                # Register the model
                # There are other ways to use the Model Registry, which depends on the use case,
                # please refer to the doc for more information:
                # https://mlflow.org/docs/latest/model-registry.html#api-workflow
                mlflow.keras.log_model(self.model, "model", registered_model_name="VGG16Model")
            else:
                mlflow.keras.log_model(self.model, "model")

try:
    config = ConfigurationManager()
    eval_config = config.get_evaluation_config()
    evaluation = Evaluation(eval_config)
    evaluation.evaluation()
    evaluation.log_into_mlflow()

except Exception as e:
   raise e
# Out:
# [2024-02-24 03:34:33,200: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-02-24 03:34:33,203: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-02-24 03:34:33,204: INFO: common: created directory at: artifacts]
# Found 30 images belonging to 2 classes.
# WARNING:tensorflow:From c:\Users\Subhr\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# [2024-02-24 03:34:34,653: WARNING: module_wrapper: From c:\Users\Subhr\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# ]
# 2/2 [==============================] - 7s 3s/step - loss: 10.7973 - accuracy: 0.5000
# [2024-02-24 03:34:40,755: INFO: common: json file saved at: scores.json]
# 2024/02/24 03:34:43 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: C:\Users\Subhr\AppData\Local\Temp\tmphw5mrl9q\model\data\model\assets
# [2024-02-24 03:34:46,965: INFO: builder_impl: Assets written to: C:\Users\Subhr\AppData\Local\Temp\tmphw5mrl9q\model\data\model\assets]
# c:\Users\Subhr\anaconda3\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Successfully registered model 'VGG16Model'.
# 2024/02/24 03:36:00 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: VGG16Model, version 1
# Created version '1' of model 'VGG16Model'.

# %%
try:
    config = ConfigurationManager()
    eval_config = config.get_evaluation_config()
    evaluation = Evaluation(eval_config)
    evaluation.evaluation()
    evaluation.log_into_mlflow()

except Exception as e:
   raise e
# Out:
# [2024-02-24 03:36:19,163: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-02-24 03:36:19,163: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-02-24 03:36:19,163: INFO: common: created directory at: artifacts]
# Found 30 images belonging to 2 classes.
# 2/2 [==============================] - 7s 3s/step - loss: 10.7973 - accuracy: 0.5000
# [2024-02-24 03:36:26,444: INFO: common: json file saved at: scores.json]
# 2024/02/24 03:36:27 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: C:\Users\Subhr\AppData\Local\Temp\tmpcqifdj2y\model\data\model\assets
# [2024-02-24 03:36:31,410: INFO: builder_impl: Assets written to: C:\Users\Subhr\AppData\Local\Temp\tmpcqifdj2y\model\data\model\assets]
# Registered model 'VGG16Model' already exists. Creating a new version of this model...
# 2024/02/24 03:37:57 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: VGG16Model, version 2
# Created version '2' of model 'VGG16Model'.
